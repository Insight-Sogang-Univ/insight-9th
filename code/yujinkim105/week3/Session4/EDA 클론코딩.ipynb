# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# !pip install IPython
from IPython.display import Image

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Requirement already satisfied: IPython in c:\users\user\anaconda3\lib\site-packages (7.29.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from IPython) (3.0.20)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from IPython) (2.10.0)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.1.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\user\anaconda3\lib\site-packages (from IPython) (5.1.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from IPython) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from IPython) (58.0.4)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)

# %%
pwd
# Out:
# 'C:\\Users\\user\\Downloads\\Session 4. EDA'

# %%
data=pd.read_csv('C:\\Users\\user\\Downloads\\Session 4. EDA\\train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Feature 분석 및 시각화

# %% [markdown]
# ## Feature의 종류

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

x=[1,2,3]
y=[2,4,6]
fig, ax=plt.subplots(2,3,figsize=(15,10))
fig.suptitle('graphs')

#graph1
ax[0,0].bar(x,y,label='label')
ax[0,0].set_title('number1')
ax[0,0].legend()
ax[0,0].set(xlabel='x_data',ylabel='y_data')

#graph2
ax[0,2].set_title('number2')

#graph3
ax[0,2].set_title('number3')

#graph4
ax[1,0].set_title('number4')

#graph5
ax[1,1].set_title('number5')

#graph6
ax[1,2].set_title('number6')
# Out:
# Text(0.5, 1.0, 'number6')

# %%
fig=plt.figure()
fig.suptitle('figure sample plots')

fig, ax_lst=plt.subplots(2,2,figsize=(8,5))

ax_lst[0][0].plot([1,2,3,4], 'ro-')
ax_lst[0][1].plot(np.random.randn(4, 10), np.random.randn(4,10), 'bo--')
ax_lst[1][0].plot(np.linspace(0.0, 5.0), np.cos(2 * np.pi * np.linspace(0.0, 5.0)))
ax_lst[1][1].plot([3,5], [3,5], 'bo:')
ax_lst[1][1].plot([3,7], [5,4], 'kx')
plt.show()

# %%
parameters = {
    'axes.titlesize': 25,
    'axes.labelsize': 20,
    'ytick.labelsize': 20
}
plt.rcParams.update(parameters)

# %% [markdown]
# ## 피처별 시각화 및 결측값 채우기

# %% [markdown]
# ### 생존자 수

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%',ax=ax[0], shadow=True,fontsize=20)
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ### 생존자 성별

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.barh(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')

plt.show()

# %% [markdown]
# ### Pclaass

# %%
pd.crosstab(data.Pclass,data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_55297_row0_col0, #T_55297_row1_col1, #T_55297_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_55297_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_55297_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_55297_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_55297_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_55297_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_55297_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_55297_row3_col0, #T_55297_row3_col1, #T_55297_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_55297_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55297_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_55297_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_55297_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_55297_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_55297_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_55297_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_55297_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_55297_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_55297_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_55297_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_55297_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_55297_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_55297_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_55297_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_55297_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_55297_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot = sns.catplot(x="Fare", y="Survived", row="Pclass",
                kind="box", orient="h", height=1.5, aspect=4,data=data.query("Fare > 0"))
plot.set(xscale="log");

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data['Pclass'].value_counts().plot.barh(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0]) 
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_09ce8_row0_col0, #T_09ce8_row0_col1, #T_09ce8_row0_col3, #T_09ce8_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_09ce8_row0_col2, #T_09ce8_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_09ce8_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_09ce8_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_09ce8_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_09ce8_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_09ce8_row2_col1, #T_09ce8_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_09ce8_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_09ce8_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_09ce8_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_09ce8_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_09ce8_row4_col0, #T_09ce8_row4_col1, #T_09ce8_row4_col2, #T_09ce8_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09ce8_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09ce8_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_09ce8_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_09ce8_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_09ce8_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_09ce8_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_09ce8_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_09ce8_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_09ce8_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_09ce8_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_09ce8_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_09ce8_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_09ce8_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_09ce8_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_09ce8_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_09ce8_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_09ce8_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_09ce8_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_09ce8_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_09ce8_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_09ce8_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_09ce8_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_09ce8_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_09ce8_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_09ce8_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_09ce8_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_09ce8_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_09ce8_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_09ce8_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %%
print('Oldest Passenger was of:', data['Age'].max(), 'Years') 
print('Youngest Passenger was of:', data['Age'].min(), 'Years') 
print('Average Age on the ship:', data['Age'].mean(), 'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

sns.violinplot('Pclass','Age',hue='Survived',data=data,split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

sns.violinplot('Sex', 'Age', hue='Survived', data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7ce84_row0_col0, #T_7ce84_row0_col1, #T_7ce84_row0_col3, #T_7ce84_row0_col4, #T_7ce84_row0_col5, #T_7ce84_row0_col7, #T_7ce84_row0_col8, #T_7ce84_row0_col12, #T_7ce84_row0_col15, #T_7ce84_row0_col16, #T_7ce84_row1_col2, #T_7ce84_row1_col6, #T_7ce84_row1_col9, #T_7ce84_row1_col10, #T_7ce84_row1_col11, #T_7ce84_row1_col13, #T_7ce84_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7ce84_row0_col2, #T_7ce84_row0_col6, #T_7ce84_row0_col9, #T_7ce84_row0_col10, #T_7ce84_row0_col11, #T_7ce84_row0_col13, #T_7ce84_row0_col14, #T_7ce84_row1_col0, #T_7ce84_row1_col1, #T_7ce84_row1_col3, #T_7ce84_row1_col4, #T_7ce84_row1_col5, #T_7ce84_row1_col7, #T_7ce84_row1_col8, #T_7ce84_row1_col12, #T_7ce84_row1_col15, #T_7ce84_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ce84_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th class="col_heading level0 col0" >Capt</th>
#       <th class="col_heading level0 col1" >Col</th>
#       <th class="col_heading level0 col2" >Countess</th>
#       <th class="col_heading level0 col3" >Don</th>
#       <th class="col_heading level0 col4" >Dr</th>
#       <th class="col_heading level0 col5" >Jonkheer</th>
#       <th class="col_heading level0 col6" >Lady</th>
#       <th class="col_heading level0 col7" >Major</th>
#       <th class="col_heading level0 col8" >Master</th>
#       <th class="col_heading level0 col9" >Miss</th>
#       <th class="col_heading level0 col10" >Mlle</th>
#       <th class="col_heading level0 col11" >Mme</th>
#       <th class="col_heading level0 col12" >Mr</th>
#       <th class="col_heading level0 col13" >Mrs</th>
#       <th class="col_heading level0 col14" >Ms</th>
#       <th class="col_heading level0 col15" >Rev</th>
#       <th class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ce84_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_7ce84_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7ce84_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7ce84_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_7ce84_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7ce84_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7ce84_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7ce84_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7ce84_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_7ce84_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_7ce84_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_7ce84_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_7ce84_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_7ce84_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7ce84_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_7ce84_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_7ce84_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_7ce84_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ce84_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_7ce84_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7ce84_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_7ce84_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7ce84_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7ce84_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_7ce84_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_7ce84_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7ce84_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_7ce84_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_7ce84_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_7ce84_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_7ce84_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_7ce84_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_7ce84_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_7ce84_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_7ce84_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_7ce84_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col','Rev', 'Capt', 'Sir', 'Don'
], ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other','Other', 'Mr', 'Mr', 'Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### age별 결측값 채우기

# %%
data.loc[(data.Age.isnull()) & (data.Initial == 'Mr'), 'Age'] = 33
data.loc[(data.Age.isnull()) & (data.Initial == 'Mrs'), 'Age'] = 36
data.loc[(data.Age.isnull()) & (data.Initial == 'Master'), 'Age'] = 5
data.loc[(data.Age.isnull()) & (data.Initial == 'Miss'), 'Age'] = 22
data.loc[(data.Age.isnull()) & (data.Initial == 'Other'), 'Age'] = 46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))

data[data['Survived'] == 0].Age.plot.hist(ax=ax[0],bins=20, edgecolor='black',color='red')

ax[0].set_title('Survived= 0')
x1 = list(range(0, 85, 5))
ax[0].set_xticks(x1)

data[data['Survived'] == 1].Age.plot.hist(ax=ax[1],color='green',bins=20, edgecolor='black')

ax[1].set_title('Survived= 1')
x2 = list(range(0, 85, 5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
plt.show()

# %% [markdown]
# ### Embarked: Categorical Value

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f71c3_row0_col0, #T_f71c3_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_f71c3_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_f71c3_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_f71c3_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_f71c3_row0_col4, #T_f71c3_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_f71c3_row1_col0, #T_f71c3_row3_col0, #T_f71c3_row3_col1, #T_f71c3_row3_col2, #T_f71c3_row3_col3, #T_f71c3_row3_col4, #T_f71c3_row4_col0, #T_f71c3_row4_col2, #T_f71c3_row4_col3, #T_f71c3_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f71c3_row1_col1, #T_f71c3_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_f71c3_row1_col3, #T_f71c3_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_f71c3_row2_col0, #T_f71c3_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_f71c3_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_f71c3_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_f71c3_row2_col4, #T_f71c3_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_f71c3_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_f71c3_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_f71c3_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_f71c3_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_f71c3_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_f71c3_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_f71c3_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_f71c3_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_f71c3_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_f71c3_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_f71c3_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_f71c3_row7_col3, #T_f71c3_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_f71c3_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_f71c3_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_f71c3_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_f71c3_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_f71c3_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_f71c3_row9_col0, #T_f71c3_row9_col1, #T_f71c3_row9_col2, #T_f71c3_row9_col3, #T_f71c3_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f71c3_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th class="col_heading level0 col0" colspan="2">female</th>
#       <th class="col_heading level0 col2" colspan="2">male</th>
#       <th class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >0</th>
#       <th class="col_heading level1 col3" >1</th>
#       <th class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f71c3_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_f71c3_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_f71c3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f71c3_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_f71c3_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_f71c3_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_f71c3_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_f71c3_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f71c3_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_f71c3_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_f71c3_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_f71c3_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_f71c3_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_f71c3_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_f71c3_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_f71c3_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_f71c3_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_f71c3_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_f71c3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f71c3_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f71c3_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_f71c3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_f71c3_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_f71c3_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_f71c3_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_f71c3_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_f71c3_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_f71c3_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_f71c3_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_f71c3_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_f71c3_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_f71c3_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_f71c3_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_f71c3_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_f71c3_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_f71c3_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_f71c3_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_f71c3_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_f71c3_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_f71c3_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_f71c3_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_f71c3_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_f71c3_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_f71c3_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_f71c3_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_f71c3_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_f71c3_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_f71c3_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_f71c3_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_f71c3_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_f71c3_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_f71c3_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_f71c3_row9_col1" class="data row9 col1" >231</td>
#       <td id="T_f71c3_row9_col2" class="data row9 col2" >468</td>
#       <td id="T_f71c3_row9_col3" class="data row9 col3" >109</td>
#       <td

# %%
sns.factorplot('Embarked', 'Survived', data=data) 
fig = plt.gcf() 
fig.set_size_inches(5, 3) 
plt.show()

# %%
f, ax = plt.subplots(2, 2, figsize=(20, 15))

sns.countplot('Embarked', data=data, ax=ax[0, 0])
ax[0, 0].set_title('No. Of Passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0, 1])
ax[0, 1].set_title('Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1, 0])
ax[1, 0].set_title('Embarked vs Survived')

sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1, 1])
ax[1, 1].set_title('Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=data)
plt.show()

# %% [markdown]
# ### Embarked 결측값 채우기

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_237ff_row0_col0, #T_237ff_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_237ff_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_237ff_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_237ff_row2_col0, #T_237ff_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_237ff_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_237ff_row3_col0, #T_237ff_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_237ff_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_237ff_row5_col0, #T_237ff_row5_col1, #T_237ff_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_237ff_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_237ff_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_237ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_237ff_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_237ff_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_237ff_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_237ff_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_237ff_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_237ff_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_237ff_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_237ff_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_237ff_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_237ff_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_237ff_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_237ff_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_237ff_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_237ff_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_237ff_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot('SibSp', 'Survived', data=data)
plt.title('SibSp vs Survived')
# Out:
# Text(0.5, 1.0, 'SibSp vs Survived')

# %%
sns.factorplot('SibSp', 'Survived', data=data)
plt.title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7e7b1_row0_col0, #T_7e7b1_row0_col1, #T_7e7b1_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_7e7b1_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_7e7b1_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_7e7b1_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_7e7b1_row2_col0, #T_7e7b1_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_7e7b1_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_7e7b1_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_7e7b1_row3_col0, #T_7e7b1_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_7e7b1_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_7e7b1_row4_col0, #T_7e7b1_row4_col1, #T_7e7b1_row5_col0, #T_7e7b1_row5_col1, #T_7e7b1_row5_col2, #T_7e7b1_row6_col0, #T_7e7b1_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7e7b1_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_7e7b1_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e7b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e7b1_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_7e7b1_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_7e7b1_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e7b1_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_7e7b1_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_7e7b1_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e7b1_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_7e7b1_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_7e7b1_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e7b1_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_7e7b1_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7e7b1_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e7b1_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7e7b1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7e7b1_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e7b1_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7e7b1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_7e7b1_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7e7b1_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_7e7b1_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_7e7b1_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_7e7b1_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Parch

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_57a71_row0_col0, #T_57a71_row0_col1, #T_57a71_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_57a71_row1_col0 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_57a71_row1_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_57a71_row1_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_57a71_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_57a71_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_57a71_row2_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_57a71_row3_col0, #T_57a71_row4_col1, #T_57a71_row5_col0, #T_57a71_row5_col1, #T_57a71_row6_col0, #T_57a71_row6_col1, #T_57a71_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_57a71_row3_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_57a71_row3_col2, #T_57a71_row4_col0, #T_57a71_row4_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_57a71_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# </style>
# <table id="T_57a71_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57a71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57a71_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_57a71_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_57a71_row0_col2" class="data row0 col2" >381</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57a71_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_57a71_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_57a71_row1_col2" class="data row1 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57a71_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_57a71_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_57a71_row2_col2" class="data row2 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57a71_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_57a71_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_57a71_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57a71_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_57a71_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_57a71_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57a71_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_57a71_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_57a71_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_57a71_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_57a71_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_57a71_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_57a71_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot('Parch', 'Survived', data=data)
plt.title('Parch vs Survived')
plt.show()

# %%
sns.factorplot('Parch', 'Survived', data=data, ax=ax[1])
plt.title('Parch vs Survived')
plt.show()

# %% [markdown]
# ### Fare

# %%
print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was:', data['Fare'].min())
print('Average Fare was:', data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
sns.catplot(x='Pclass', y='Fare', hue='Sex', data=data)

# %%
f, ax = plt.subplots(1, 3, figsize=(20, 8))

sns.distplot(data[data['Pclass'] == 1].Fare, ax=ax[0], color='r')
ax[0].set_title('Fares in Pclass 1')

sns.distplot(data[data['Pclass'] == 2].Fare, ax=ax[1], color='y')
ax[1].set_title('Fares in Pclass 2')

sns.distplot(data[data['Pclass'] == 3].Fare, ax=ax[2], color='g')
ax[2].set_title('Fares in Pclass 3')

plt.show()

# %% [markdown]
# ## Correlation Beteween the Features

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2) 
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# # Feature Engineering & Data cleaning

# %% [markdown]
# ## Age_band

# %%
data['Age_band'] = 0
data.loc[data['Age'] <= 16, 'Age_band'] = 0
data.loc[(data['Age'] > 16) & (data['Age'] <= 32), 'Age_band'] = 1
data.loc[(data['Age'] > 32) & (data['Age'] <= 48), 'Age_band'] = 2
data.loc[(data['Age'] > 48) & (data['Age'] <= 64), 'Age_band'] = 3
data.loc[data['Age'] > 64, 'Age_band'] = 4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_17da0_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_17da0_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_17da0_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_17da0_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_17da0_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17da0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age_band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17da0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_17da0_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_17da0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_17da0_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
#       <th id="T_17da0_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_17da0_row2_col0" class="data row2 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_17da0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17da0_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_17da0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_17da0_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Age_band', 'Survived', data=data, col='Pclass')
plt.show()

# %% [markdown]
# ## Family_Size and Alone

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch'] + data['SibSp']  
data['Alone'] = 0
data.loc[data.Family_Size == 0, 'Alone'] = 1  

sns.factorplot('Family_Size', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')

sns.factorplot('Alone', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')

plt.show()

# %%
sns.factorplot('Alone', 'Survived', data=data, hue='Sex', col='Pclass')
plt.show()

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4) 
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fa0b1_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fa0b1_row1_col0 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_fa0b1_row2_col0 {
#   background-color: #54aa66;
#   color: #f1f1f1;
# }
# #T_fa0b1_row3_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fa0b1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa0b1_level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#       <td id="T_fa0b1_row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>
#     <tr>
#       <th id="T_fa0b1_level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#       <td id="T_fa0b1_row1_col0" class="data row1 col0" >0.303571</td>
#     </tr>
#     <tr>
#       <th id="T_fa0b1_level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#       <td id="T_fa0b1_row2_col0" class="data row2 col0" >0.454955</td>
#     </tr>
#     <tr>
#       <th id="T_fa0b1_level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#       <td id="T_fa0b1_row3_col0" class="data row3 col0" >0.581081</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Fare_cat'] = 0
data.loc[data['Fare'] <= 7.91, 'Fare_cat'] = 0
data.loc[(data['Fare'] > 7.91) & (data['Fare'] <= 14.454), 'Fare_cat'] = 1
data.loc[(data['Fare'] > 14.454) & (data['Fare'] <= 31), 'Fare_cat'] = 2
data.loc[(data['Fare'] > 31) & (data['Fare'] <= 513), 'Fare_cat'] = 3

# %%
sns.factorplot('Fare_cat', 'Survived', data=data, hue='Sex')
plt.show()

# %% [markdown]
# ## Converting String Values into Numeric

# %%
data['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
data['Initial'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'],[0, 1, 2, 3, 4],inplace=True)

# %% [markdown]
# ## Dropping UnNeeded Features

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Initial', 'Age_band',
#        'Family_Size', 'Alone', 'Fare_Range', 'Fare_cat'],
#       dtype='object')

# %%
data.drop(
    ['Name', 'Age', 'Ticket', 'Fare', 'Cabin', 'Fare_Range', 'PassengerId'],
    axis=1,
    inplace=True)
sns.heatmap(data.corr(), annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size': 20})
fig = plt.gcf()
fig.set_size_inches(18, 15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 시각화 기본 보충

# %% [markdown]
# ## Line Plot

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(axis=0), columns=['A','B','C','D'], index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0   0.797025 -1.449179  0.057616 -1.964933
# 10 -1.555345 -1.171822  0.034287 -3.173351
# 20 -4.166024 -1.835525  2.071752 -3.722516
# 30 -4.124903 -4.863313  1.401374 -4.114286
# 40 -4.341455 -5.647041  2.363715 -4.369856
# 50 -2.906922 -5.243051  1.884763 -5.647671
# 60 -3.670653 -5.325152  2.026050 -3.588250
# 70 -4.413758 -5.762211  1.220431 -4.611622
# 80 -4.215404 -6.072836  2.511715 -4.427880
# 90 -4.333853 -7.376594  3.160910 -4.873886

# %%
df.plot(marker='o', color=['r','b','g','y'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## IRIS dataset

# %%
iris = sns.load_dataset("iris") #iris 데이터
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Scatter Plot

# %%
plt.plot('petal_length',  'petal_width',  data=iris,linestyle='none', marker='o', markersize=6,color='purple', alpha=0.5)
plt.title('Scatter Plot of Petal size', fontsize=20)
plt.xlabel('petal_length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.show()

# %%
plt.plot('petal_length',  # x
         'petal_width',  # y
         data=iris[iris['species']=='setosa'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='purple', 
         alpha=0.5)
plt.plot('petal_length',  # x
         'petal_width',  # y
         data=iris[iris['species']=='versicolor'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='blue', 
         alpha=0.75)
plt.plot('petal_length',  # x
         'petal_width',  # y
         data=iris[iris['species']=='virginica'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='green', 
         alpha=0.75)
plt.title('Scatter Plot of PETAL', fontsize=20)
plt.xlabel('petal_length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.legend(['setosa','versicolor', 'virginica'])
plt.show()

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6);

# %% [markdown]
# ## 데이터 전처리 Scaling 시각화

# %%
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8, 
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7, 
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
import numpy as np

fish_data= np.column_stack((fish_length, fish_weight))
fish_target= np.concatenate((np.ones(35), np.zeros(14)))
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(fish_data, fish_target, random_state=42)

from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
distances, indexes = kn.kneighbors([[25,150]])

import matplotlib.pyplot as plt
plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25,150,marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1],marker='D')
plt.xlabel('length')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25, 150, marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1], marker='D')
plt.xlim((0,1000))
plt.xlabel("length")
plt.ylabel("weight")
plt.show()

# %%
mean=np.mean(train_input, axis=0)
std=np.std(train_input, axis=0)

# %%
print(mean,std)
# Out:
# [ 26.175      418.08888889] [ 10.21073441 321.67847023]

# %%
train_scaled=(train_input-mean)/std

# %%
plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(25, 150, marker='^')
plt.xlabel("length")
plt.ylabel('weight')
plt.show()

# %%
new=([25,150]-mean)/std
plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(new[0], new[1], marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
