# %% [markdown]
# 1. 수치 기술 통계량 이해하기 (평균 / 분산 / 상관계수 등)
# 2. 여러 분포 / 표본 / 모집단 / 이론 이해하기
# 3. 가설검정의 절차와 해석에 대해 이해하기
# *전반적으로 경영통계학 내용이랑 상당히 겹치는듯하다.
#
# I. 수치 기술 통계량들에 대해 ~ Descriptive (테크닉 아님!)
# 1 중심위치 척도 종류 ~ 평균 / 중앙값 / 최빈값 : 그때그때 써야함,, skewness 참조
# 2 변동성 척도 종류 ~ 사분위수 / IQR / 범위 / 분산 / 표준편차 / 변동계수
# 3 연관성 척도 종류 ~ 공분산 / 상관계수 (상관관계 <>인과관계) / 기타 상관계수(파이, 스피어만, 점-양분?)
#
# II. 추측통계 ~ 모집단 분포 추정
# - 확률분포
#     이산확률분포 : 베르누이 / 기하 / 초기하 / 포아송
#     연속확률분포 : 정규분포 / T분포 / F분포 / 감마분포 / 지수분포 / 카이제곱 / 베타 / 균일
#
# - 그 중 많이 쓰는 것들 ~ 경영통계학 수업때 했던것들 참고
# 정규분포 / T분호 / 카이제곱분포 / F분포 / 이항분포 / 포아송분포
# 자유도 개념 **
#
# III. 모집단과 표본집단의 차이
# 모수 알 수 없으니까 표본 쓰는거가 기본
# => 그래서 추정한다
# - 대수의 법칙 / 라플라스 정리 ~ 표본 수 많으면 모수와 비슷해지더라
# - 중심극한정리 ~ 표본 수 많아지면 정규분포에 가까워지더라
#
# IV. 가설검정
# 절차 : 가설 설정 => 유의수준 설정 => 검정통계량 산출 => 기각/채택 판단
# 귀무가설 ~ 1종오류 (맞는데 틀리다고 하기) / 2종오류 (틀린데 맞다고 하기)
#
# V. 기타
# 조건부확률과 베이스 정리 (이것도 시험 나왔던거다 경통때)
