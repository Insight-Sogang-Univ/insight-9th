# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# !pip install IPython
from IPython.display import Image

import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Requirement already satisfied: IPython in c:\users\user\anaconda3\lib\site-packages (7.31.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\user\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from IPython) (63.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from IPython) (3.0.20)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from IPython) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)

# %%
data = pd.read_csv('./train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

x=[1,2,3]
y=[2,4,6]
fig, ax = plt.subplots(2,3, figsize=(15,10))
fig.suptitle('graphs')

ax[0,0].bar(x, y, label='label')
ax[0,0].set_title('number1')
ax[0,0].legend() #범례설정
ax[0,0].set(xlabel='x_data',ylabel='y_data')

ax[0,1].set_title('number2')

ax[0,2].set_title('number3')

ax[1,0].set_title('number4')

ax[1,1].set_title('number5')

ax[1,2].set_title('number6')
# Out:
# Text(0.5, 1.0, 'number6')

# %%
fig = plt.figure()
fig.suptitle('figure sample plots')

fig, ax_lst = plt.subplots(2, 2, figsize=(8,5))

ax_lst[0][0].plot([1,2,3,4], 'ro-')
ax_lst[0][1].plot(np.random.randn(4, 10), np.random.randn(4,10), 'bo--')
ax_lst[1][0].plot(np.linspace(0.0, 5.0), np.cos(2 * np.pi * np.linspace(0.0, 5.0)))
ax_lst[1][1].plot([3,5], [3,5], 'bo:')
ax_lst[1][1].plot([3,7], [5,4], 'kx')
plt.show()

# %%
parameters = {
    'axes.titlesize': 25,
    'axes.labelsize': 20,
    'ytick.labelsize': 20
}
plt.rcParams.update(parameters)

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data['Survived'].value_counts().plot.pie(explode=[0, 0.1],
                                         autopct='%1.1f%%',
                                         ax=ax[0],
                                         shadow=True,
                                         fontsize=20)
ax[0].set_title('Survived') 
ax[0].set_ylabel('')

sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.barh(ax=ax[0]) 
ax[0].set_title('Survived vs Sex') 

sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')

plt.show()

# %%
Image("1234.jpg.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: '1234.jpg.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: '1234.jpg.png'

# %%
pd.crosstab(data.Pclass,
            data.Survived, margins=True).style.background_gradient(
                cmap='summer_r')
# Out:
# <style type="text/css">
# #T_37aa9_row0_col0, #T_37aa9_row1_col1, #T_37aa9_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_37aa9_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_37aa9_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_37aa9_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_37aa9_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_37aa9_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_37aa9_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_37aa9_row3_col0, #T_37aa9_row3_col1, #T_37aa9_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_37aa9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_37aa9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_37aa9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_37aa9_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37aa9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_37aa9_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_37aa9_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_37aa9_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_37aa9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_37aa9_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_37aa9_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_37aa9_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_37aa9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_37aa9_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_37aa9_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_37aa9_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_37aa9_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_37aa9_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_37aa9_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_37aa9_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot = sns.catplot(x="Fare", y="Survived", row="Pclass",
                kind="box", orient="h", height=1.5, aspect=4,
                data=data.query("Fare > 0")) 
plot.set(xscale="log");

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data['Pclass'].value_counts().plot.barh(
    color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0]) 
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

sns.countplot(x='Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass,
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_0878c_row0_col0, #T_0878c_row0_col1, #T_0878c_row0_col3, #T_0878c_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_0878c_row0_col2, #T_0878c_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_0878c_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_0878c_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_0878c_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_0878c_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_0878c_row2_col1, #T_0878c_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_0878c_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_0878c_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_0878c_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_0878c_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_0878c_row4_col0, #T_0878c_row4_col1, #T_0878c_row4_col2, #T_0878c_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0878c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_0878c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_0878c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_0878c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_0878c_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0878c_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_0878c_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_0878c_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_0878c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_0878c_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_0878c_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_0878c_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_0878c_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_0878c_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_0878c_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_0878c_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_0878c_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_0878c_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_0878c_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_0878c_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_0878c_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_0878c_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_0878c_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_0878c_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_0878c_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_0878c_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_0878c_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_0878c_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_0878c_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_0878c_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_0878c_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_0878c_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_0878c_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %%
print('Oldest Passenger was of:', data['Age'].max(), 'Years') 
print('Youngest Passenger was of:', data['Age'].min(), 'Years') 
print('Average Age on the ship:', data['Age'].mean(), 'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

sns.violinplot('Pclass',
               'Age',
               hue='Survived',
               data=data,
               split=True, 
               ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

sns.violinplot('Sex', 'Age', hue='Survived', data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(
    cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9096f_row0_col0, #T_9096f_row0_col1, #T_9096f_row0_col3, #T_9096f_row0_col4, #T_9096f_row0_col5, #T_9096f_row0_col7, #T_9096f_row0_col8, #T_9096f_row0_col12, #T_9096f_row0_col15, #T_9096f_row0_col16, #T_9096f_row1_col2, #T_9096f_row1_col6, #T_9096f_row1_col9, #T_9096f_row1_col10, #T_9096f_row1_col11, #T_9096f_row1_col13, #T_9096f_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9096f_row0_col2, #T_9096f_row0_col6, #T_9096f_row0_col9, #T_9096f_row0_col10, #T_9096f_row0_col11, #T_9096f_row0_col13, #T_9096f_row0_col14, #T_9096f_row1_col0, #T_9096f_row1_col1, #T_9096f_row1_col3, #T_9096f_row1_col4, #T_9096f_row1_col5, #T_9096f_row1_col7, #T_9096f_row1_col8, #T_9096f_row1_col12, #T_9096f_row1_col15, #T_9096f_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9096f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_9096f_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_9096f_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_9096f_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_9096f_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_9096f_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_9096f_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_9096f_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_9096f_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_9096f_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_9096f_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_9096f_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_9096f_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_9096f_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_9096f_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_9096f_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_9096f_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_9096f_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9096f_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_9096f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9096f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9096f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9096f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9096f_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_9096f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9096f_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9096f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_9096f_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_9096f_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_9096f_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_9096f_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_9096f_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_9096f_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_9096f_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_9096f_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_9096f_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9096f_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_9096f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9096f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_9096f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9096f_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_9096f_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_9096f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_9096f_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_9096f_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_9096f_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_9096f_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_9096f_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_9096f_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_9096f_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_9096f_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_9096f_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_9096f_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_9096f_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Initial'].replace([
    'Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col',
    'Rev', 'Capt', 'Sir', 'Don'
], [
    'Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other',
    'Other', 'Mr', 'Mr', 'Mr'
],
                        inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data.loc[(data.Age.isnull()) & (data.Initial == 'Mr'), 'Age'] = 33
data.loc[(data.Age.isnull()) & (data.Initial == 'Mrs'), 'Age'] = 36
data.loc[(data.Age.isnull()) & (data.Initial == 'Master'), 'Age'] = 5
data.loc[(data.Age.isnull()) & (data.Initial == 'Miss'), 'Age'] = 22
data.loc[(data.Age.isnull()) & (data.Initial == 'Other'), 'Age'] = 46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))

data[data['Survived'] == 0].Age.plot.hist(ax=ax[0],
                                          bins=20,
                                          edgecolor='black',
                                          color='red')
ax[0].set_title('Survived= 0')
x1 = list(range(0, 85, 5))
ax[0].set_xticks(x1)

data[data['Survived'] == 1].Age.plot.hist(ax=ax[1],
                                          color='green',
                                          bins=20,
                                          edgecolor='black')
ax[1].set_title('Survived= 1')
x2 = list(range(0, 85, 5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
plt.show()

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1d8c3_row0_col0, #T_1d8c3_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_1d8c3_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_1d8c3_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_1d8c3_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_1d8c3_row0_col4, #T_1d8c3_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_1d8c3_row1_col0, #T_1d8c3_row3_col0, #T_1d8c3_row3_col1, #T_1d8c3_row3_col2, #T_1d8c3_row3_col3, #T_1d8c3_row3_col4, #T_1d8c3_row4_col0, #T_1d8c3_row4_col2, #T_1d8c3_row4_col3, #T_1d8c3_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1d8c3_row1_col1, #T_1d8c3_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_1d8c3_row1_col3, #T_1d8c3_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_1d8c3_row2_col0, #T_1d8c3_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_1d8c3_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_1d8c3_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_1d8c3_row2_col4, #T_1d8c3_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_1d8c3_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_1d8c3_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_1d8c3_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_1d8c3_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_1d8c3_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_1d8c3_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_1d8c3_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_1d8c3_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_1d8c3_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_1d8c3_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_1d8c3_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_1d8c3_row7_col3, #T_1d8c3_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_1d8c3_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_1d8c3_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_1d8c3_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_1d8c3_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_1d8c3_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_1d8c3_row9_col0, #T_1d8c3_row9_col1, #T_1d8c3_row9_col2, #T_1d8c3_row9_col3, #T_1d8c3_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1d8c3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_1d8c3_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_1d8c3_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_1d8c3_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_1d8c3_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_1d8c3_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_1d8c3_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_1d8c3_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_1d8c3_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d8c3_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_1d8c3_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_1d8c3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1d8c3_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_1d8c3_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_1d8c3_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_1d8c3_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_1d8c3_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_1d8c3_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_1d8c3_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_1d8c3_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_1d8c3_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_1d8c3_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_1d8c3_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_1d8c3_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_1d8c3_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_1d8c3_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_1d8c3_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_1d8c3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_1d8c3_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_1d8c3_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_1d8c3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_1d8c3_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_1d8c3_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_1d8c3_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_1d8c3_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_1d8c3_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_1d8c3_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_1d8c3_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_1d8c3_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_1d8c3_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_1d8c3_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_1d8c3_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_1d8c3_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_1d8c3_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_1d8c3_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_1d8c3_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_1d8c3_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_1d8c3_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_1d8c3_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_1d8c3_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_1d8c3_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_1d8c3_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_1d8c3_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_1d8c3_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_1d8c3_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_1d8c3_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_1d8c3_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_1d8c3_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c3_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_1d8c3_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_1d8c3_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
sns.factorplot('Embarked', 'Survived', data=data) 
fig = plt.gcf() 
fig.set_size_inches(5, 3) 
plt.show()

# %%
f, ax = plt.subplots(2, 2, figsize=(20, 15))


sns.countplot('Embarked', data=data, ax=ax[0, 0])
ax[0, 0].set_title('No. Of Passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0, 1])
ax[0, 1].set_title('Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1, 0])
ax[1, 0].set_title('Embarked vs Survived')

sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1, 1])
ax[1, 1].set_title('Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=data)
plt.show()

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %%
pd.crosstab([data.SibSp],
            data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fc0a5_row0_col0, #T_fc0a5_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_fc0a5_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_fc0a5_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_fc0a5_row2_col0, #T_fc0a5_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_fc0a5_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_fc0a5_row3_col0, #T_fc0a5_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_fc0a5_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_fc0a5_row5_col0, #T_fc0a5_row5_col1, #T_fc0a5_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fc0a5_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_fc0a5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_fc0a5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fc0a5_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc0a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc0a5_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_fc0a5_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc0a5_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_fc0a5_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc0a5_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_fc0a5_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc0a5_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_fc0a5_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc0a5_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_fc0a5_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc0a5_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_fc0a5_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc0a5_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_fc0a5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_fc0a5_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot('SibSp', 'Survived', data=data)
plt.title('SibSp vs Survived')
# Out:
# Text(0.5, 1.0, 'SibSp vs Survived')

# %%
sns.factorplot('SibSp', 'Survived', data=data)
plt.title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e32f1_row0_col0, #T_e32f1_row0_col1, #T_e32f1_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e32f1_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_e32f1_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_e32f1_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_e32f1_row2_col0, #T_e32f1_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_e32f1_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_e32f1_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_e32f1_row3_col0, #T_e32f1_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_e32f1_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_e32f1_row4_col0, #T_e32f1_row4_col1, #T_e32f1_row5_col0, #T_e32f1_row5_col1, #T_e32f1_row5_col2, #T_e32f1_row6_col0, #T_e32f1_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e32f1_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_e32f1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_e32f1_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e32f1_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e32f1_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e32f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e32f1_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_e32f1_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_e32f1_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e32f1_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_e32f1_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_e32f1_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e32f1_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_e32f1_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_e32f1_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e32f1_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_e32f1_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_e32f1_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e32f1_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_e32f1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e32f1_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e32f1_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e32f1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_e32f1_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e32f1_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_e32f1_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e32f1_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_e32f1_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_74d90_row0_col0, #T_74d90_row0_col1, #T_74d90_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_74d90_row1_col0 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_74d90_row1_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_74d90_row1_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_74d90_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_74d90_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_74d90_row2_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_74d90_row3_col0, #T_74d90_row4_col1, #T_74d90_row5_col0, #T_74d90_row5_col1, #T_74d90_row6_col0, #T_74d90_row6_col1, #T_74d90_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_74d90_row3_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_74d90_row3_col2, #T_74d90_row4_col0, #T_74d90_row4_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_74d90_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# </style>
# <table id="T_74d90">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_74d90_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_74d90_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_74d90_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74d90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74d90_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_74d90_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_74d90_row0_col2" class="data row0 col2" >381</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74d90_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_74d90_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_74d90_row1_col2" class="data row1 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74d90_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_74d90_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_74d90_row2_col2" class="data row2 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74d90_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_74d90_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_74d90_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74d90_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_74d90_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_74d90_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74d90_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_74d90_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_74d90_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_74d90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_74d90_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_74d90_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_74d90_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot('Parch', 'Survived', data=data)
plt.title('Parch vs Survived')
plt.show()

# %%
sns.factorplot('Parch', 'Survived', data=data, ax=ax[1])
plt.title('Parch vs Survived')
plt.show()

# %%
print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was:', data['Fare'].min())
print('Average Fare was:', data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
sns.catplot(x='Pclass', y='Fare', hue='Sex', data=data)

# %%
f, ax = plt.subplots(1, 3, figsize=(20, 8))

sns.distplot(data[data['Pclass'] == 1].Fare, ax=ax[0], color='r')
ax[0].set_title('Fares in Pclass 1')

sns.distplot(data[data['Pclass'] == 2].Fare, ax=ax[1], color='y')
ax[1].set_title('Fares in Pclass 2')

sns.distplot(data[data['Pclass'] == 3].Fare, ax=ax[2], color='g')
ax[2].set_title('Fares in Pclass 3')

plt.show()

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2) 
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.show()

# %%
data['Age_band'] = 0
data.loc[data['Age'] <= 16, 'Age_band'] = 0
data.loc[(data['Age'] > 16) & (data['Age'] <= 32), 'Age_band'] = 1
data.loc[(data['Age'] > 32) & (data['Age'] <= 48), 'Age_band'] = 2
data.loc[(data['Age'] > 48) & (data['Age'] <= 64), 'Age_band'] = 3
data.loc[data['Age'] > 64, 'Age_band'] = 4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(
    cmap='summer')
# Out:
# <style type="text/css">
# #T_41ebe_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_41ebe_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_41ebe_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_41ebe_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_41ebe_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41ebe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41ebe_level0_col0" class="col_heading level0 col0" >Age_band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41ebe_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_41ebe_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_41ebe_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_41ebe_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
#       <th id="T_41ebe_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_41ebe_row2_col0" class="data row2 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_41ebe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41ebe_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_41ebe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41ebe_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Age_band', 'Survived', data=data, col='Pclass')
plt.show()

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch'] + data['SibSp']  
data['Alone'] = 0
data.loc[data.Family_Size == 0, 'Alone'] = 1  

sns.factorplot('Family_Size', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')

sns.factorplot('Alone', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')

plt.show()

# %%
sns.factorplot('Alone', 'Survived', data=data, hue='Sex', col='Pclass')
plt.show()

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4) 
data.groupby([
    'Fare_Range'
])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f7b8a_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f7b8a_row1_col0 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_f7b8a_row2_col0 {
#   background-color: #54aa66;
#   color: #f1f1f1;
# }
# #T_f7b8a_row3_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7b8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7b8a_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7b8a_level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#       <td id="T_f7b8a_row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>
#     <tr>
#       <th id="T_f7b8a_level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#       <td id="T_f7b8a_row1_col0" class="data row1 col0" >0.303571</td>
#     </tr>
#     <tr>
#       <th id="T_f7b8a_level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#       <td id="T_f7b8a_row2_col0" class="data row2 col0" >0.454955</td>
#     </tr>
#     <tr>
#       <th id="T_f7b8a_level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#       <td id="T_f7b8a_row3_col0" class="data row3 col0" >0.581081</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Fare_cat'] = 0
data.loc[data['Fare'] <= 7.91, 'Fare_cat'] = 0
data.loc[(data['Fare'] > 7.91) & (data['Fare'] <= 14.454), 'Fare_cat'] = 1
data.loc[(data['Fare'] > 14.454) & (data['Fare'] <= 31), 'Fare_cat'] = 2
data.loc[(data['Fare'] > 31) & (data['Fare'] <= 513), 'Fare_cat'] = 3

# %%
sns.factorplot('Fare_cat', 'Survived', data=data, hue='Sex')
plt.show()

# %%
data['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
data['Initial'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'],
                        [0, 1, 2, 3, 4],
                        inplace=True)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Initial', 'Age_band',
#        'Family_Size', 'Alone', 'Fare_Range', 'Fare_cat'],
#       dtype='object')

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(axis=0), columns=['A','B','C','D'], index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0   0.486109  0.317514 -0.366185  0.732078
# 10  1.320061  0.536861 -0.290701 -0.044485
# 20  0.615972 -0.853797 -0.519373  0.729596
# 30 -0.456508 -0.973859 -3.335659  1.103177
# 40  0.557316 -0.119393 -0.915702  1.147989
# 50  1.923039 -1.888366 -0.342254  1.839570
# 60  2.199886 -2.541544 -0.148570  0.992754
# 70  2.256135 -5.040682  0.151733  1.286816
# 80  2.381511 -4.157393 -0.205755  0.957096
# 90  3.255136 -5.148289 -0.571957 -1.227724

# %%
df.plot(marker='o', color=['r','b','g','y'])
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset("iris") 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.plot('petal_length', 
         'petal_width', 
         data=iris,
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='purple', 
         alpha=0.5)
plt.title('Scatter Plot of Petal size', fontsize=20)
plt.xlabel('petal_length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.show()

# %%
plt.plot('petal_length',  
         'petal_width',  
         data=iris[iris['species']=='setosa'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='purple', 
         alpha=0.5)
plt.plot('petal_length',  
         'petal_width',  
         data=iris[iris['species']=='versicolor'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='blue', 
         alpha=0.75)
plt.plot('petal_length', 
         'petal_width',  
         data=iris[iris['species']=='virginica'],
         linestyle='none', 
         marker='o', 
         markersize=6,
         color='green', 
         alpha=0.75)
plt.title('Scatter Plot of PETAL', fontsize=20)
plt.xlabel('petal_length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.legend(['setosa','versicolor', 'virginica'])
plt.show()

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6);

# %%
import numpy as np

fish_data= np.column_stack((fish_length, fish_weight))
fish_target= np.concatenate((np.ones(35), np.zeros(14)))
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(fish_data, fish_target, random_state=42)

from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\3668245293.py in <module>
#       1 import numpy as np
#       2
# ----> 3 fish_data= np.column_stack((fish_length, fish_weight))
#       4 fish_target= np.concatenate((np.ones(35), np.zeros(14)))
#       5 from sklearn.model_selection import train_test_split
#
# NameError: name 'fish_length' is not defined

# %%
distances, indexes = kn.kneighbors([[25,150]])

import matplotlib.pyplot as plt
plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25,150,marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1],marker='D')
plt.xlabel('length')
plt.ylabel('weight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\4113066001.py in <module>
# ----> 1 distances, indexes = kn.kneighbors([[25,150]])
#       2
#       3 import matplotlib.pyplot as plt
#       4 plt.scatter(train_input[:,0], train_input[:,1])
#       5 plt.scatter(25,150,marker='^')
#
# NameError: name 'kn' is not defined

# %%
plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25, 150, marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1], marker='D')
plt.xlim((0,1000))
plt.xlabel("length")
plt.ylabel("weight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\794543071.py in <module>
# ----> 1 plt.scatter(train_input[:,0], train_input[:,1])
#       2 plt.scatter(25, 150, marker='^')
#       3 plt.scatter(train_input[indexes,0], train_input[indexes,1], marker='D')
#       4 plt.xlim((0,1000))
#       5 plt.xlabel("length")
#
# NameError: name 'train_input' is not defined

# %%
mean=np.mean(train_input, axis=0)
std=np.std(train_input, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\3495388461.py in <module>
# ----> 1 mean=np.mean(train_input, axis=0)
#       2 std=np.std(train_input, axis=0)
#
# NameError: name 'train_input' is not defined

# %%
print(mean,std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\2152120242.py in <module>
# ----> 1 print(mean,std)
#
# NameError: name 'mean' is not defined

# %%
train_scaled=(train_input-mean)/std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\2912338177.py in <module>
# ----> 1 train_scaled=(train_input-mean)/std
#
# NameError: name 'train_input' is not defined

# %%
plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(25, 150, marker='^')
plt.xlabel("length")
plt.ylabel('weight')
print('Oldest Passenger was of:', data['Age'].max(), 'Years') 
print('Youngest Passenger was of:', data['Age'].min(), 'Years') 
print('Average Age on the ship:', data['Age'].mean(), 'Years')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\1729549516.py in <module>
# ----> 1 plt.scatter(train_scaled[:,0], train_scaled[:,1])
#       2 plt.scatter(25, 150, marker='^')
#       3 plt.xlabel("length")
#       4 plt.ylabel('weight')
#       5 print('Oldest Passenger was of:', data['Age'].max(), 'Years')
#
# NameError: name 'train_scaled' is not defined

# %%
new=([25,150]-mean)/std
plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(new[0], new[1], marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20764\3114634268.py in <module>
# ----> 1 new=([25,150]-mean)/std
#       2 plt.scatter(train_scaled[:,0], train_scaled[:,1])
#       3 plt.scatter(new[0], new[1], marker='^')
#       4 plt.xlabel('length')
#       5 plt.ylabel('weight')
#
# NameError: name 'mean' is not defined
